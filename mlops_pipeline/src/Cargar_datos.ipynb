# %% [markdown]
# # Cargar Datos
#
# Este notebook se encarga de cargar los datos desde el archivo `Base_de_datos.xlsx` y realizar una inspección inicial.

# %%
import pandas as pd
import os

# Definir ruta al archivo de datos
# Asumiendo que el notebook está en mlops_pipeline/src y los datos en la raíz
data_path = '../../Base_de_datos.xlsx'

if os.path.exists(data_path):
    print(f"Archivo encontrado en: {data_path}")
else:
    print(f"Archivo no encontrado en: {data_path}")

# %%
# Cargar datos
try:
    df = pd.read_excel(data_path)
    print("Datos cargados exitosamente.")
except Exception as e:
    print(f"Error al cargar los datos: {e}")

# %%
# Inspección inicial
print("Primeras 5 filas:")
display(df.head())

# %%
print("\nInformación del DataFrame:")
df.info()

# %%
print("\nEstadísticas descriptivas:")
display(df.describe())

# %%
# Guardar el dataframe procesado (si fuera necesario) o listo para el paso siguiente
# En este caso, solo mostramos que cargamos los datos correctamente.
